# %% [markdown]
# # APUNTES CLASIFICACIÓN

# %% [markdown]
# A partir de muhos datos de una parte de train para clasificar entre las categorías que hemos identificado como target.
#
# Un modelo no se puede tratar con valores nulos.
#
# Agrupa ocurrencias en tipos.
#
# La mejor metrica es el accuracy, el porcentaje.
#
# Aquí el corte es el 50%. Un modelo del 50% indica aleatoriedad. Un valor < 50 significa que se está haciendo algo mal. Sieve sobre todo para modelos binarios. Dependerá del numero de variables. En valores binarios se puede alcanzar accuracy de 99%.
#
# Entre 4 clases o tipos clasificatorios el limite de corte es del 25%. Aquí un accuracy de un 60% es bueno.
#
# resanpling = generar datos sinteticos, datos de diferentes fuentes.
#
# Dentro del accuracy se puede ver el nivel de precisión de los aciertos (matriz de confusión)
