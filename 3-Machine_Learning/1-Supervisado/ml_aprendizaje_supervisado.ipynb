# %% [markdown]
# # ANÁLISIS SUPERVISADO

# %% [markdown]
# En este momento, una columna va a ser una variable. En el aprendizaje supervisado, se identifica una variable target.

# %% [markdown]
# A la hora de seleccionar las variables que necesitamos, es bueno sacar un heatmap con las correlaciones entra las variables (columnas).

# %% [markdown]
# Métrica de evaluación. Mide la fiabilidad del modelo.

# %% [markdown]
# Test: sirve para evualuar la fiabilidad de los modelos. Se usa con modelos de calsificación no con los modelos regresivos.

# %% [markdown]
# En los modelos de regresión, la fiabilidad se mide con el error medio absoluto (MAE).

# %% [markdown]
# A la hora de elegir un modelo, una cosa es un error y otro es los falsos positivos o falsos negativos.

# %% [markdown]
# La mayoria de los modelos se basan en regresiones lineales. Interesan valores cercanos a la linea de regresión

# %% [markdown]
# El modelo de regresión polinómica se usan mas como preprocesamiento.

# %% [markdown]
# El MAE depende de nuestra variable target. No es lo mismo un MAE de 1000 euros si hablamos de coches (más precisión) que si hablas de ordenadores (menos precisón)

# %% [markdown]
# Que un modelo no generaliza bien sisgnifica que un modelo empieza a fallar con datos ajenos a nuestro dataset.

# %% [markdown]
# TRAIN/TEST. DE 10.000 REGISTROS, COGEMOS 8000 PARA TRAIN Y DEJAMOS 2000 PARA TEST
#
# Si el dataset es pequeño, lo recomendable es bajar el test, ya que cuantos más datos tengamos para el train mejor.

# %% [markdown]
# EJEMPLO:
#
# Price es Y, la variable (columna) target, x es el resto de variables con las que se comapra la target.

# %% [markdown]
# A partir de las variables de x, se reliza la predicción de y (Price)
#
# X_TRAIN - Y_TRAIN
# X_TEST - Y_TEST - PREDICT

# %% [markdown]
# La generalización de un modelo se refiere a su comportamiento ante nuevos datos respecto a los que se le han pasado inicialmente.

# %% [markdown]
# No hay modelo mágico, ante underfitting no funciona pasarle mas datos y ante el overfitting pasarle menos (mirar ejemplo de los perros)

# %% [markdown]
# Interesa encontrar el punto en el que el error de entrenamiento con nuestros datos y el error con datos nuevos (test) este en el punto mas bajo y mas juntos (mirar BIAS vs Variance)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# sklearn - Machine learning
#
# tensorflow - keras - Deep Learning

# %% [markdown]
# 5 BLOQUES IMPORTANTES PARA UN CIENTIFICO DE DATOS A LA HORA DE HACER UN MODELO PREDICITIVO DE DATOS. NO TIENE POR QUÉ ESTAR HECHO UN BLOQUE PARA PASAR EL SIGUIENTE:
#
# 1. FUENTES DE DATOS (csv, json, API, consulta SQL a bas de datos, web scraping...) - resultado en dataframe.
#
# 2. ANÁLISIS DE DATOS. Con este análisis se entienden bien los datos: distribución de datos, identificar el target, ver si hay datos que aporten...
#
# 3. TRANSFORMACIÓN DE DATOS. Aquí entra la analitica predicitiva. Adaptar los datos a los algoritmos de Machien Learning (Los datos descriptivos no los acepta). Se transforman esas variables categóricas a variables numéricas. Veremos correlaciones para ver las variables interesantes.
#
# 4. MODELO DE ML (definición, entrenamiento...). si elegiremos un modelo de regresión o clasificación, que modelo de regresión se adapta mejor, luego se parametriza ese modelo..
#
# 5. EVALUACIÓN DEL MODELO DE ML. Evaluar como de bueno es el modelo con el TRAIN/TEST.
