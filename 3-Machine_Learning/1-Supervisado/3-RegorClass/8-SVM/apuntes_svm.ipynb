# %% [markdown]
# Es como una regresión polinómica, pero ajusta el plano a los datos

# %% [markdown]
# Un parametro importante es el kernel

# %% [markdown]
# El SVM juega mucho con los márgenes, se pinta la linea que mas margenes tnega para medir la tolerancia, espacios en los que se va a tolerar un fallo. Si se ajustan mucho los margenes se puede generalizar peor. Se se paramtrizan margenes mas anchos, generaliza mejor.

# %% [markdown]
# Hiperplano optimo de separación, aquel que consige mayores margenes

# %% [markdown]
# kernel = grado de en el que puede adaptarse el hiperplano
#
# kernel lineal
#
# kernel no lineal

# %% [markdown]
# Genera una hiperparametrizacion muy grande  y por tanto genera caja negra, es decir, no se sabe como funciona.
