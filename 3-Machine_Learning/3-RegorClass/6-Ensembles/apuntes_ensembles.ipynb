# %% [markdown]
# # ENSEMBLES

# %% [markdown]
# Permite combinar modelos trabajando simultaneamente.a

# %% [markdown]
# - combinacion de mismos modelos (Bagging y Boosting)
#
# - combinacion de modelos diferentes

# %% [markdown]
# No podemos mezclar regresión y clasificación.

# %% [markdown]
# #### Clasificacion
#
# - hard voting (valores mas repetido): se vasa en el predict, cuando interesa centrarse en la recall (ejemplo datos médicos), funciona mejor para modelos
# binarios.
#
# - soft voting: se basa en el predict_proba
#
# #### Rregresion
#
# Se basa tb en el predict, saca la media de las predicciones de varios modelos

# %% [markdown]
# El voting permite trabajar con varios modelos a la vez. Se basa en como se devuelven las predicciones.

# %% [markdown]
# Dentro de lo ensebles pueden ser:
#
# - del mismo tipo de modelo
#
#     - Bagging: dentro del mismo modelo, definimos cuandos modelos queremos (knn - knn - knn o DecissionTree - DecissionTree - DecissionTree). Usa hard voting y soft voting. Con boosting a True se pasan distintos train a los DT, a False, se
#     - Pasting
#
# - de distintos tipos de modelo:
#
#     - voting (Linear Regression, Ridge y RandomForest por ejemplo, esto devuelve la media de las predicciones)
#
#
# Dentro de los ensembles, podemos tener que uno de los modelos sirva para que los otros aprendadn
#
# knn_1  = devuelve prediccion
#
# knn_2 = usa la anterior predicción para asignar pesos y devuelve predicción.
#
# knn_3 = usa la anterior predicción para asignar pesos y devuelve predicción.
#
# RandomForest es una variante de bagging, usa voting.

# %% [markdown]
# El boosting los modelos se entrenan secuencialmente = dependencia entre ellos. Cada modelo intenta mejorar las predicciones del anterior a partir de los errores que le llegan. Con este modelo, en recursos, baja en rendimiento.
#
# Ensembes de boosting que funcionan como modelos propios
#
#     - Adaboost. Como un Randomforest pero de boosting, que trabaja con modelos secuencialmnte. Cada modelo pasa su alfa al siguiente. Actualiza pesos
#         - dos opciones
#             - quedarte con el valor del ultimo modelo o hacer un voting
#
#     - Gradient Boosting. Minimiza los errores (residuos) del modelo predecesor.
#     - XG
