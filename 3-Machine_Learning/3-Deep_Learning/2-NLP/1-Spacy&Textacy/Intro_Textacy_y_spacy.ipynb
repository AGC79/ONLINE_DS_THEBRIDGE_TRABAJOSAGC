# %% [markdown]
# # Textacy & Spacy
# Librerias de procesado de NLP

# %%
'''
Versiones compatibles
Despues hay que reiniciar el entorno de ejecución
'''
# !pip install spacy
# !pip install textacy

# # Para siguientes ejecuciones, solo ejecutar esto y reiniciar despues el entorno
# !python -m spacy download en_core_web_lg
# !python -m spacy download es_core_news_lg
# Out:
# '\nVersiones compatibles\nDespues hay que reiniciar el entorno de ejecución\n'

# %% [markdown]
# # Spacy
# https://spacy.io/
#
# NOTA: Recuerda reiniciar el entorno de ejecucion despues de la instalacion

# %%
import spacy

nlp = spacy.load("es_core_news_lg")

# %% [markdown]
# ## Text basics
# Veamos como trabajar cn estos primeros ejemplos con la libreria ´spacy´. Cosas que podemos hacer:
# 1. Tokenizar en frases
# 2. Tokenizar en palabras
# 3. Acceder a los atributos de cada token
# 4. Acceder a las entidades del texto
# 5. Visualizar las entidades del texto

# %%
text = """Galopaba con un furor demente, como si la fervorosa sangre guerrera de sus antepasados 
le corriera por las venas con un fuego nuevo; y transportado por Crinblanca parecía un dios de la antigüedad, 
el propio Orome el Grande, se hubiera dicho, en la batalla de Valar, cuando el mundo era joven. El escudo de oro 
resplandecía y centelleaba como una imagen del sol,y la hierba reverdecía alrededor de las patas del caballo. 
Pues llegaba la mañana, la mañana y un viento del mar; y ya se disipaban las tinieblas; y los hombres 
de Mordor gemían, y conocían el pánico, y huían y morían, y los cascos de la ira pasaban sobre ellos. 
Y de pronto los ejércitos de Rohan rompieron a cantar, y cantaban mientras mataban, 
pues el júbilo de la batalla estaba en todos ellos, y los sonidos de ese canto que era hermoso y terrible llegaron aun a la ciudad.
"""

doc = nlp(text)

print(doc)

for num, sentence in enumerate(doc.sents):
  print(num, sentence)
# Out:
# Galopaba con un furor demente, como si la fervorosa sangre guerrera de sus antepasados
# le corriera por las venas con un fuego nuevo; y transportado por Crinblanca parecía un dios de la antigüedad,
# el propio Orome el Grande, se hubiera dicho, en la batalla de Valar, cuando el mundo era joven. El escudo de oro
# resplandecía y centelleaba como una imagen del sol,y la hierba reverdecía alrededor de las patas del caballo.
# Pues llegaba la mañana, la mañana y un viento del mar; y ya se disipaban las tinieblas; y los hombres
# de Mordor gemían, y conocían el pánico, y huían y morían, y los cascos de la ira pasaban sobre ellos.
# Y de pronto los ejércitos de Rohan rompieron a cantar, y cantaban mientras mataban,
# pues el júbilo de la batalla estaba en todos ellos, y los sonidos de ese canto que era hermoso y terrible llegaron aun a la ciudad.
#
# 0 Galopaba con un furor demente, como si la fervorosa sangre guerrera de sus antepasados
# le corriera por las venas con un fuego nuevo; y transportado por Crinblanca parecía un dios de la antigüedad,
# el propio Orome el Grande, se hubiera dicho, en la batalla de Valar, cuando el mundo era joven.
# 1 El escudo de oro
# resplandecía y centelleaba como una imagen del sol,y la hierba reverdecía alrededor de las patas del caballo.
# 2
#
# 3 Pues llegaba la mañana, la mañana y un viento del mar; y ya se disipaban las tinieblas; y los hombres
# de Mordor gemían, y conocían el pánico, y huían y morían, y los cascos de la ira pasaban sobre ellos.
#
# 4 Y de pronto los ejércitos de Rohan rompieron a cantar, y cantaban mientras mataban,
# pues el júbilo de la batalla estaba en todos ellos, y los sonidos de ese canto que era hermoso y terrible llegaron aun a la ciudad.

# %%
len(list(doc.sents))
# Out:
# 5

# %%
for word in doc[:20]:
  print(word.text, word.lemma_, word.pos_, word.is_stop)
# Out:
# Galopaba galopar VERB False
# con con ADP True
# un uno DET True
# furor furor NOUN False
# demente demente ADV False
# , , PUNCT False
# como como SCONJ True
# si si SCONJ True
# la el DET True
# fervorosa fervoroso ADJ False
# sangre sangre NOUN False
# guerrera guerrero ADJ False
# de de ADP True
# sus su DET True
# antepasados antepasado NOUN False
#
#
#  SPACE False
# le él PRON True
# corriera correr VERB False
# por por ADP True
# las el DET True

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %% [markdown]
# ## Syntactic analysis
# Doing the school homework

# %%
from spacy import displacy

doc2 = nlp("Ojalá El anillo nunca hubiera llegado a mí. Ojalá nada hubiera ocurrido.")
displacy.render(doc2, jupyter=True, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="81aeb03f333342fe98be1cb78774a5b1-0" class="displacy" width="2150" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Ojalá</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">El</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">anillo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">nunca</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">hubiera</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">llegado</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">mí.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Ojalá</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">nada</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">hubiera</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">ocurrido.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-81aeb03f333342fe98be1cb78774a5b1-0-0" stroke-width="2px" d="M70,352.0 C70,2.0 925.0,2.0 925.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-81aeb03f333342fe98be1cb78774a5b1-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-81aeb03f333342fe98be1cb78774a5b1-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-81aeb03f333342fe98be1cb78774a5b1-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-81aeb03f333342fe98be1cb78774a5b1-0-2" stroke-width="2px" d="M420,352.0 C420,89.5 920.0,89.5 920.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-81aeb03f333342fe98be1cb78774a5b1-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-81aeb03f333342fe98be1cb78774a5b1-0-3" stroke-width="2px" d="M595,352.0 C595,177.0 915.0,177.0 915.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-81aeb03f333342fe98be1cb78774a5b1-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-81aeb03f333342fe98be1cb78774a5b1-0-4" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-81aeb03f333342fe98be1cb78774a5b1-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-81aeb03f333342fe98be1cb78774a5b1-0-5" stroke-width="2px" d="M1120,352.0 C1120,264.5 1260.0,264.5 1260.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-81aeb03f333342fe98be1cb78774a5b1-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,354.0 L1112,342.0 1128,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-81aeb03f333342fe98be1cb78774a5b1-0-6" stroke-width="2px" d="M945,352.0 C945,177.0 1265.0,177.0 1265.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-81aeb03f333342fe98be1cb78774a5b1-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1265.0,354.0 L1273.0,342.0 1257.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-81aeb03f333342fe98be1cb78774a5b1-0-7" stroke-width="2px" d="M1470,352.0 C1470,89.5 1970.0,89.5 1970.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-81aeb03f333342fe98be1cb78774a5b1-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1470,354.0 L1462,342.0 1478,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-a

# %% [markdown]
# ## Entities in text

# %%
for entity in doc.ents:
  print(entity.text, entity.label_, spacy.explain(entity.label_))
# Out:
# Crinblanca LOC Non-GPE locations, mountain ranges, bodies of water
# Orome el Grande PER Named person or family.
# batalla de Valar MISC Miscellaneous entities, e.g. events, nationalities, products or works of art
# El escudo de oro MISC Miscellaneous entities, e.g. events, nationalities, products or works of art
# Mordor LOC Non-GPE locations, mountain ranges, bodies of water
# Rohan LOC Non-GPE locations, mountain ranges, bodies of water

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Galopaba con un furor demente, como si la fervorosa sangre guerrera de sus antepasados <br>le corriera por las venas con un fuego nuevo; y transportado por
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crinblanca
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  parecía un dios de la antigüedad, <br>el propio
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Orome el Grande
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , se hubiera dicho, en la
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     batalla de Valar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , cuando el mundo era joven.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El escudo de oro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  <br>resplandecía y centelleaba como una imagen del sol,y la hierba reverdecía alrededor de las patas del caballo. <br>Pues llegaba la mañana, la mañana y un viento del mar; y ya se disipaban las tinieblas; y los hombres <br>de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mordor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  gemían, y conocían el pánico, y huían y morían, y los cascos de la ira pasaban sobre ellos. <br>Y de pronto los ejércitos de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rohan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  rompieron a cantar, y cantaban mientras mataban, <br>pues el júbilo de la batalla estaba en todos ellos, y los sonidos de ese canto que era hermoso y terrible llegaron aun a la ciudad.<br></div></span>

# %%
nlp_es = spacy.load('es_core_news_lg')

text = '''Londres (en inglés, London, pronunciado /ˈlʌndən/ ( escuchar)) es la capital y mayor ciudad de Inglaterra y del Reino Unido.2​3​ Situada a orillas del río Támesis, Londres es un importante asentamiento humano desde que fue fundada por los romanos con el nombre de Londinium hace casi dos milenios.4​ El núcleo antiguo de la urbe, la City de Londres, conserva básicamente su perímetro medieval de una milla cuadrada. Desde el siglo XIX el nombre «Londres» también hace referencia a toda la metrópolis desarrollada alrededor de este núcleo.5​ El grueso de esta conurbación forma la región de Londres y el área administrativa del Gran Londres,6​ gobernado por el alcalde y la asamblea de Londres.7​
Londres es una ciudad global, uno de los centros neurálgicos en el ámbito de las artes, el comercio, la educación, el entretenimiento, la moda, las finanzas, los medios de comunicación, la investigación, el turismo o el transporte.8​ Es el principal centro financiero del mundo9​10​11​ y una de las áreas metropolitanas con mayor PIB.12​13​ Londres es también una capital cultural mundial,14​15​16​17​ la ciudad más visitada considerando el número de visitas internacionales18​ y tiene el mayor sistema aeroportuario del mundo según el tráfico de pasajeros.19​ Asimismo, las 43 universidades de la ciudad conforman la mayor concentración de centros de estudios superiores de toda Europa.20​ En el año 2012 Londres se convirtió en la única ciudad en albergar la celebración de tres Juegos Olímpicos de Verano.21​
En esta ciudad multirracial convive gente de un gran número de culturas que hablan más de trescientos idiomas distintos.22​ La Autoridad del Gran Londres estima que en 2015 la ciudad tiene 8,63 millones de habitantes,23​ que supone el 12,5 % del total de habitantes del Reino Unido.24​ El área urbana del Gran Londres, con 10 470 00025​ habitantes, es la segunda más grande de Europa, pero su área metropolitana, con una población estimada de entre 12 y 14 millones,26​27​ es la mayor del continente. Desde 1831 a 1925 Londres, como capital del Imperio británico, fue la ciudad más poblada del mundo.'''
doc = nlp_es(text)

# Para ver las entidades que ha detectado
for entity in doc.ents:
    print(f"{entity.text} ({entity.label_})")
# Out:
# Londres (LOC)
# London (LOC)
# Inglaterra (LOC)
# Reino Unido.2​3​ Situada (LOC)
# Támesis (LOC)
# Londres (LOC)
# Londinium (LOC)
# El núcleo antiguo de la urbe (MISC)
# City de Londres (LOC)
# Londres (LOC)
# Londres (LOC)
# Gran Londres,6​ (LOC)
# Londres.7​
# Londres (LOC)
# Londres (LOC)
# Londres (LOC)
# Juegos Olímpicos de Verano.21​
# En esta ciudad multirracial convive gente de un gran número de culturas (MISC)
# La Autoridad del Gran Londres (MISC)
# Reino Unido.24​ El área urbana del (LOC)
# Gran Londres (LOC)
# Europa (LOC)
# Londres (LOC)
# Imperio británico (LOC)

# %%
# Doubts with labels
spacy.explain('MISC')
# Out:
# 'Miscellaneous entities, e.g. events, nationalities, products or works of art'

# %% [markdown]
# ## Most frequent words
# In a Wikipedia page

# %%
# !pip install wikipedia

# %%
from spacy.lang.es.stop_words import STOP_WORDS

# %%
len(list(STOP_WORDS))
# Out:
# 521

# %%
list(STOP_WORDS)[:20]
# Out:
# ['ésta',
#  'nosotras',
#  'ciertos',
#  'debajo',
#  'sigue',
#  'siete',
#  'ustedes',
#  'poco',
#  'apenas',
#  'dia',
#  'supuesto',
#  'varias',
#  'aquí',
#  'conseguir',
#  'delante',
#  'ésas',
#  'próximo',
#  'mi',
#  'todavia',
#  'buenos']

# %%
import wikipedia
wikipedia.set_lang("es")
wiki = wikipedia.page(title="Fernando Alonso")
text = wiki.content
text[0:1000]
# Out:
# 'Fernando Alonso Díaz (Oviedo, 29 de julio de 1981) es un piloto de automovilismo español, galardonado con el Premio Príncipe de Asturias en 2005. Ganó dos veces el Campeonato Mundial de Fórmula 1 en 2005 y 2006 con el equipo Renault,\u200b resultó subcampeón en 2010, 2012 y 2013 con la escudería Ferrari, y obtuvo un tercer puesto en 2007 con McLaren. Fue campeón del Campeonato Mundial de Resistencia de la FIA en 2019 y del Campeonato Mundial de Karting en 1996, y vencedor de las 24 Horas de Le Mans en 2018 y 2019, y de las 24 Horas de Daytona en 2019. En 2017 fue incluido en el Salón de la Fama de la FIA,\u200b y en 2019 volvió a entrar como campeón del WEC, convirtiéndose en el primer piloto de la historia en estar dos veces en el Salón de la Fama.\u200b\nEn su carrera en Fórmula 1, ha competido para los equipos Minardi, Renault, McLaren, Ferrari, Alpine y Aston Martin. Con la escudería francesa Renault, logró tanto el Campeonato de Pilotos como el Campeonato de Constructores junto a Giancarlo Fisich'

# %%
nombres = [w.text.lower() for w in nlp(text) if ((not w.is_stop) and (not w.is_punct) and (w.pos_ == 'ADJ'))]
nombres[:10]
# Out:
# ['español',
#  'galardonado',
#  'tercer',
#  'francesa',
#  'consecutivas',
#  'numerosos',
#  'joven',
#  'empatado',
#  'lleno',
#  'cuarto']

# %%
from collections import Counter
word_freq = Counter(nombres)

word_freq.most_common(10)[1:]
# Out:
# [('cuarto', 15),
#  ('español', 14),
#  ('séptimo', 13),
#  ('sexto', 12),
#  ('tercer', 10),
#  ('noveno', 10),
#  ('quinta', 10),
#  ('octavo', 10),
#  ('oficial', 9)]

# %%
wikipedia.set_lang("es")
wiki = wikipedia.page(title="Regresión Lineal")
text = wiki.content
text[0:1000]
# Out:
# 'En estadística, la regresión lineal o ajuste lineal es un modelo matemático usado para aproximar la relación de dependencia entre una variable dependiente \n  \n    \n      \n        Y\n      \n    \n    {\\displaystyle Y}\n  \n, \n  \n    \n      \n        m\n      \n    \n    {\\displaystyle m}\n  \n variables independientes \n  \n    \n      \n        \n          X\n          \n            i\n          \n        \n      \n    \n    {\\displaystyle X_{i}}\n  \n con \n  \n    \n      \n        m\n        ∈\n        \n          \n            Z\n          \n          \n            +\n          \n        \n      \n    \n    {\\displaystyle m\\in \\mathbb {Z} ^{+}}\n  \n y un término aleatorio \n  \n    \n      \n        ε\n      \n    \n    {\\displaystyle \\varepsilon }\n  \n. Este método es aplicable en muchas situaciones en las que se estudia la relación entre dos o más variables o predecir un comportamiento, algunas incluso sin relación con la tecnología. En caso de que no se pueda aplicar un modelo de regresión a un estudio, se dice que no hay corr'

# %%
nombres = [w.lemma_ for w in nlp_es(text) if ((not w.is_stop) and (not w.is_punct) and (w.pos_ == 'ADJ'))]
nombres[:10]
# Out:
# ['lineal',
#  'lineal',
#  'matemático',
#  'usado',
#  'dependiente',
#  'independiente',
#  '\\displaystyle',
#  '\\displaystyle',
#  'aleatorio',
#  'aplicable']

# %%
from collections import Counter
word_freq = Counter(nombres)

word_freq.most_common(10)[1:]
# Out:
# [('obtenido', 11),
#  ('\\displaystyle', 8),
#  ('múltiple', 8),
#  ('independiente', 7),
#  ('cuadrado', 7),
#  ('simple', 7),
#  ('dependiente', 6),
#  ('aleatorio', 6),
#  ('llamado', 6)]

# %% [markdown]
# ## Textacy London text
# No we want to know things about London, from our previous text

# %%
# import spacy
import textacy.extract

#### CODE ####

# The text we want to examine
text = """London is the capital and most populous city of England and the United Kingdom. Standing on the River Thames in the south east of the island of Great Britain, London has been a major settlement for two millennia. London was founded by the Romans, 
who named it Londinium. London is a huge city. London has a lot of cute restaurants. Jaimito is my best friend.
"""

doc = nlp(text)
statements = textacy.extract.semistructured_statements(doc, entity="London", cue='be')

# Print the results
print("Here are the things I know about London:")

for statement in statements:
    subject, verb, fact = statement
    print(f" - {fact}")
# Out:
# Here are the things I know about London:
#  - [the, capital, and, most, populous, city, of, England, and, the, United, Kingdom]
#  - [a, major, settlement, for, two, millennia]
#  - [a, huge, city]

# %%
# nlp_es = spacy.load('es_core_news_lg')

# doc = nlp(wiki.content)

# statements = textacy.extract.semistructured_statements(doc, entity="Benzema", cue='be')

# # Print the results
# print("Here are the things I know about Karim:")

# for statement in statements:
#     subject, verb, fact = statement
#     print(f" - {fact}")

# %% [markdown]
# ## Textacy with Wikipedia API
# We don't want the most frequent words, we want sentences about London

# %%
wikipedia.set_lang("es")
london = wikipedia.page("Fernando Alonso")
text = london.content

# %%
text
# Out:
# 'Fernando Alonso Díaz (Oviedo, 29 de julio de 1981) es un piloto de automovilismo español, galardonado con el Premio Príncipe de Asturias en 2005. Ganó dos veces el Campeonato Mundial de Fórmula 1 en 2005 y 2006 con el equipo Renault,\u200b resultó subcampeón en 2010, 2012 y 2013 con la escudería Ferrari, y obtuvo un tercer puesto en 2007 con McLaren. Fue campeón del Campeonato Mundial de Resistencia de la FIA en 2019 y del Campeonato Mundial de Karting en 1996, y vencedor de las 24 Horas de Le Mans en 2018 y 2019, y de las 24 Horas de Daytona en 2019. En 2017 fue incluido en el Salón de la Fama de la FIA,\u200b y en 2019 volvió a entrar como campeón del WEC, convirtiéndose en el primer piloto de la historia en estar dos veces en el Salón de la Fama.\u200b\nEn su carrera en Fórmula 1, ha competido para los equipos Minardi, Renault, McLaren, Ferrari, Alpine y Aston Martin. Con la escudería francesa Renault, logró tanto el Campeonato de Pilotos como el Campeonato de Constructores junto a Giancarlo Fisichella en dos temporadas consecutivas, estableciendo numerosos récords en su momento. Se convirtió en el piloto más joven en ganar un título de Fórmula 1, con 24 años y 58 días, superando a Emerson Fittipaldi; este récord fue posteriormente superado por Lewis Hamilton en 2008 (23 años y 300 días) y luego por Sebastian Vettel en 2010 (23 años y 134 días). En 2007, terminó tercero, empatado a puntos con su compañero Lewis Hamilton y a solo un punto de Kimi Räikkönen, en un año lleno de controversia. Tras dos temporadas de transición a Renault, pasó a formar parte de la escudería de Maranello entre 2010 y 2014, donde logró tres subcampeonatos y un Grand Chelem. En 2015 regresó a McLaren-Honda, permaneciendo hasta su retirada en 2018. Tras dos años fuera de la categoría, volvió en 2021 con la escudería Alpine —parte de la familia Renault—, con la que ganó sus dos títulos. Desde 2023 forma parte del equipo Aston Martin, donde finalizó cuarto en el campeonato, logrando ocho podios y una vuelta rápida.\nHa ganado dos de las tres carreras que conforman la triple corona del automovilismo, quedándole únicamente por conseguir las 500 Millas de Indianápolis. Participó en las ediciones de 2017, 2019 y 2020 con McLaren, siendo elegido novato del año en su primera participación, en la que clasificó quinto, llegó a liderar la carrera y, a falta de 21 vueltas, su motor Honda se rompió cuando marchaba en séptima posición.\u200b También compitió en las 24 Horas de Daytona de 2018 con un Ligier para United Autosports y en las 24 Horas de Daytona de 2019 con un Cadillac para Wayne Taylor Racing. Participó además en el Campeonato Mundial de Resistencia de 2018-19 y el Rally Dakar de 2020 junto a Marc Coma para Toyota Gazoo Racing. Junto con Marc Gené y Miguel Molina, Alonso es el único español ganador absoluto de las 24 Horas de Le Mans, siendo el único en repetir victoria en la prueba.\nFernando Alonso es el piloto con más carreras comenzadas en la historia de la Fórmula 1: 425. Es el piloto con más temporadas en las que ha tomado la salida (21), el séptimo piloto con mayor número de victorias (32),\u200b el quinto piloto con más podios (igualado con Alain Prost: 106),\u200b el decimoquinto piloto con más poles (22), el noveno piloto con más vueltas rápidas (26), el tercer piloto con más circuitos con podio (igualado con Kimi Räikkönen: 30) y el quinto piloto con más Grandes Premios liderados (87), entre otros registros.\u200b Por detrás de Max Verstappen, es el piloto que más posiciones de salida diferentes ha convertido en victoria (9).\u200b Además, posee la racha más larga derrotando a su compañero de equipo en carrera: 41 frente a Felipe Massa (Gran Premio de Turquía 2011 – Gran Premio de Japón 2013).\u200b Entre sus triunfos se cuentan tres en el Gran Premio de Malasia, tres en el Gran Premio de Baréin, tres en el Gran Premio de Alemania, tres en el Gran Premio de Europa (GP-Strecke: 2005 y 2007; Valencia: 2012) y dos en el Gran Premio de Mónaco. ...

# %%
doc = nlp(text)

# Extract semi-structured statements
statements = textacy.extract.semistructured_statements(doc, entity="Fernando", cue='ganar')

# Print the results
print("Here are the things I know about London:")

for statement in statements:
    print(statement)
    subject, verb, fact = statement
    print(f" - {fact}")
    print(f" - {subject}")
    print(f" - {verb}")
# Out:
# Here are the things I know about London:
# SSSTriple(entity=[Fernando], cue=[ganó], fragment=[las, 1000, Millas, de, Sebring])
#  - [las, 1000, Millas, de, Sebring]
#  - [Fernando]
#  - [ganó]

# %%
len(doc)
# Out:
# 22470

# %%
doc
# Out:
# London is the capital and most populous city of England and the United Kingdom. Standing on the River Thames in the south east of the island of Great Britain, London has been a major settlement for two millennia. London was founded by the Romans,
# who named it Londinium. London is a huge city. London has a lot of cute restaurants. Jaimito is my best friend.
