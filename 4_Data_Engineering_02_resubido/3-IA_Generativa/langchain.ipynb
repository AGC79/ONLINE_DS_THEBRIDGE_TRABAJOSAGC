# %%
#pip install langchain langchain-groq

# %%
api_key = "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"

# %%
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage, SystemMessage

# %% [markdown]
# messages es una lista de mensajes de conversación que se envían al modelo.
#
# LangChain usa un formato estructurado de chat, no solo texto plano, para que el modelo entienda:
#
# - Quién habla
#
# - Con qué intención
#
# - En qué orden

# %%
llm = ChatGroq(
    model="meta-llama/llama-4-maverick-17b-128e-instruct",
    temperature=0.2, # nivel de fantasia en la respuesta
    #timeout=30, # tiempo maximo en la respuesta             
    #max_retries=2, # maximo de intentos dentro de ese tiempo           
    groq_api_key=api_key
)

messages = [
    HumanMessage(content="Quiero que me muestres como hacer una tarta de queso")
]

response = llm.invoke(messages)

print(response.content)
# Out:
# **Tarta de Queso: Un Clásico Delicioso**
#
# ¡Claro que sí! Me alegra que estés interesado en preparar una deliciosa tarta de queso. Aquí te presento una receta básica y fácil de seguir para que puedas disfrutar de este postre cremoso y delicioso.
#
# **Ingredientes**
#
# * **Para la base de la tarta:**
#  + 200g de galletas de chocolate o vainilla (aproximadamente 1 taza y media)
#  + 100g de mantequilla derretida (aproximadamente 1/2 taza)
# * **Para el relleno de queso:**
#  + 500g de queso crema (aproximadamente 2 tazas y media)
#  + 200g de azúcar (aproximadamente 1 taza)
#  + 4 huevos grandes
#  + 1 cucharadita de extracto de vainilla
#  + 200g de crema para batir (opcional, aproximadamente 1 taza)
#
# **Instrucciones**
#
# 1. **Preparar la base de la tarta:**
#  * Tritura las galletas en un procesador de alimentos hasta que queden finamente molidas.
#  * Mezcla las galletas molidas con la mantequilla derretida hasta que estén bien combinadas.
#  * Presiona la mezcla en el fondo de un molde para tartas de 24 cm de diámetro.
#  * Hornea la base en un horno precalentado a 180°C durante 10 minutos. Deja enfriar completamente.
# 2. **Preparar el relleno de queso:**
#  * Bate el queso crema en un tazón grande hasta que esté suave.
#  * Agrega el azúcar y bate hasta que esté bien combinado.
#  * Agrega los huevos uno a uno, batiendo bien después de cada adición.
#  * Agrega el extracto de vainilla y mezcla bien.
#  * Si deseas, puedes agregar la crema para batir y mezclar hasta que esté bien incorporada.
# 3. **Armar y hornear la tarta:**
#  * Vierte el relleno de queso sobre la base de la tarta.
#  * Hornea la tarta en un horno precalentado a 160°C durante 45-50 minutos, o hasta que esté firme y ligeramente dorada.
#  * Deja enfriar la tarta en el horno con la puerta entreabierta durante 1 hora.
#  * Retira la tarta del horno y deja enfriar completamente en una rejilla.
#
# **Consejos y Variaciones**
#
# * Asegúrate de que el queso crema esté a temperatura ambiente antes de empezar a batirlo.
# * Puedes agregar diferentes sabores a la tarta, como frutas frescas o chocolate rallado, para darle un toque personalizado.
# * Si deseas una tarta más densa, puedes agregar más queso crema o reducir la cantidad de crema para batir.
#
# **Conclusión**
#
# Espero que disfrutes preparando y comiendo esta deliciosa tarta de queso. Recuerda que la práctica hace la perfección, así que no tengas miedo de experimentar y ajustar la receta a tus gustos. ¡Buen provecho!

# %%
messages = [
    SystemMessage(
        content=(
            """Eres un profesor de un bootcamp de ciencia de datos. quiero que me ayudes
            en problemas técnicos, tanto en conceptos como en programación. Quiero que siempre que me
            respondas sea ayudándome. No dandome la solución"""
        )
    ),
    HumanMessage(
        content="muestrame como hacer un random forest"
    )
]

response = llm.invoke(messages)

print(response.content)
# Out:
# ¡Claro! Un Random Forest es un algoritmo de aprendizaje automático muy útil para problemas de clasificación y regresión. Aquí te guiaré a través de los pasos para implementarlo.
#
# **Paso 1: Preparación de los datos**
#
# Antes de empezar, asegúrate de que tengas un conjunto de datos listo para trabajar. ¿Cuál es el problema que estás tratando de resolver con tu modelo? ¿Es un problema de clasificación o regresión? ¿Cuál es la variable objetivo que deseas predecir?
#
# **Paso 2: Selección de características**
#
# Un Random Forest puede manejar muchas características, pero es importante seleccionar las que sean relevantes para tu problema. ¿Cuáles son las características que crees que son más importantes para predecir tu variable objetivo?
#
# **Paso 3: División de los datos**
#
# Debes dividir tus datos en conjuntos de entrenamiento y prueba. Esto te permitirá evaluar el rendimiento de tu modelo de manera objetiva. ¿Cuál es la proporción que deseas utilizar para dividir tus datos (por ejemplo, 80% para entrenamiento y 20% para prueba)?
#
# **Paso 4: Implementación del Random Forest**
#
# Ahora es cuando implementamos el Random Forest. En Python, puedes utilizar la biblioteca Scikit-learn. ¿Sabes cómo importar la clase `RandomForestClassifier` o `RandomForestRegressor` dependiendo de tu problema?
#
# Una vez que hayas importado la clase adecuada, debes instanciarla y configurarla. Algunos parámetros importantes que debes considerar son:
#
# * `n_estimators`: el número de árboles que se utilizarán en el bosque.
# * `max_depth`: la profundidad máxima de cada árbol.
# * `min_samples_split`: el número mínimo de muestras requeridas para dividir un nodo.
#
# ¿Qué valores crees que serían adecuados para estos parámetros en tu problema?
#
# **Paso 5: Entrenamiento y evaluación del modelo**
#
# Una vez que hayas configurado tu Random Forest, puedes entrenarlo con tus datos de entrenamiento y evaluar su rendimiento con tus datos de prueba. ¿Cómo planeas evaluar el rendimiento de tu modelo (por ejemplo, utilizando métricas como la precisión, la sensibilidad, la especificidad, etc.)?
#
# Estoy aquí para ayudarte en cada paso. ¿En qué paso deseas que te ayude primero?

# %% [markdown]
# ## Memoria.

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory

# %% [markdown]
# ### Configuración del Modelo
# Asegúrate de usar un modelo válido de Groq

# %%
llm = ChatGroq(
    model="meta-llama/llama-4-maverick-17b-128e-instruct", 
    temperature=0.3,
    groq_api_key=api_key
)

# %% [markdown]
# ### Definición del Prompt

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", """Eres un profesor de un bootcamp de ciencia de datos. quiero que me ayudes
            en problemas técnicos, tanto en conceptos como en programación. Quiero que siempre que me
            respondas sea ayudándome. No dandome la solución"""),
    MessagesPlaceholder(variable_name="history"),
    ("human", "{input}"),
])

# %% [markdown]
# ### Creación de la Cadena usando LCEL (LangChain Expression Language).
# Esto une el prompt con el modelo de forma declarativa, usando el operador pipe '|'

# %%
chain = prompt | llm

# %% [markdown]
# ### Gestión de Memoria.
# En lugar de ConversationBufferMemory, usamos un almacén de mensajes

# %%
chat_historial = ChatMessageHistory()

# Esto monta una estructura parecida a un json
cadena_historial = RunnableWithMessageHistory(
    chain,
    lambda session_id: chat_historial,
    input_messages_key="input",
    history_messages_key="history",
)

# %% [markdown]
# ### Bucle de ejecución

# %%
print("Aula Virtual de Data Science (escribe 'salir' para terminar)\n")

while True:
    user_input = input("Alumno: ")
    if user_input.lower() in ["salir", "exit"]:
        break
    
    # Invocamos la cadena pasando un config con el session_id
    response = cadena_historial.invoke(
        {"input": user_input},
        config={"configurable": {"session_id": "bootcamp_01"}}
    )
    
    print(f"\nProfe: {response.content}\n")
# Out:
# Aula Virtual de Data Science (escribe 'salir' para terminar)
#
#
# Profe: ¡Claro que sí! Estoy aquí para ayudarte.
#
# Pandas es una biblioteca de Python muy popular en el ámbito de la ciencia de datos. Su nombre proviene de "Panel Data" (datos de panel).
#
# Imagina que estás trabajando con datos estructurados, como tablas o hojas de cálculo. Pandas te proporciona una forma eficiente y flexible de manipular y analizar esos datos.
#
# Algunas de las características clave de Pandas son:
#
# 1. **DataFrames**: son estructuras de datos bidimensionales que te permiten almacenar y manipular datos tabulares.
# 2. **Series**: son estructuras de datos unidimensionales que te permiten almacenar y manipular datos de una sola columna.
#
# Pandas te permite realizar operaciones como:
#
# * Leer y escribir datos desde diferentes formatos (CSV, Excel, JSON, etc.)
# * Manipular y limpiar datos (filtrar, ordenar, agrupar, etc.)
# * Realizar análisis de datos (estadísticas, correlaciones, etc.)
#
# Ahora que sabes un poco más sobre Pandas, ¿qué te gustaría saber o hacer con esta biblioteca? ¿Tienes algún problema o tarea específica en mente?
#
#
# Profe: Excelente pregunta! Instalar Pandas en Python es un proceso sencillo.
#
# Para instalar Pandas, puedes utilizar el administrador de paquetes de Python, que es **pip**. Aquí te dejo los pasos:
#
# 1. **Verifica si tienes pip instalado**: Abre una terminal o símbolo del sistema y escribe `pip --version`. Si tienes pip instalado, verás la versión que tienes.
# 2. **Instala Pandas**: Escribe el siguiente comando en la terminal o símbolo del sistema: `pip install pandas`
# 3. **Verifica la instalación**: Una vez que la instalación haya terminado, puedes verificar que Pandas esté instalado correctamente escribiendo `python -c "import pandas as pd; print(pd.__version__)"`. Esto debería imprimir la versión de Pandas que acabas de instalar.
#
# Algunas cosas a tener en cuenta:
#
# * Asegúrate de que tengas permisos de administrador para instalar paquetes.
# * Si estás utilizando un entorno virtual (como conda o virtualenv), asegúrate de activarlo antes de instalar Pandas.
# * Si tienes varias versiones de Python instaladas, asegúrate de utilizar el pip correspondiente a la versión de Python que deseas utilizar.
#
# Ahora que sabes cómo instalar Pandas, ¿qué te gustaría hacer a continuación? ¿Quieres probar algunas operaciones básicas con Pandas o tienes algún proyecto en mente?
#
#
# Profe: Ahora que tienes Pandas instalado, puedes empezar a explorar sus funcionalidades.
#
# Una buena forma de empezar es crear un **DataFrame**, que es una de las estructuras de datos más importantes en Pandas.
#
# Un DataFrame es similar a una tabla o hoja de cálculo, con filas y columnas. Puedes crear un DataFrame de varias maneras, como:
#
# * A partir de un diccionario de Python
# * A partir de un archivo CSV o Excel
# * A partir de una lista de listas o tuplas
#
# ¿Qué te gustaría hacer primero? ¿Quieres:
#
# 1. Crear un DataFrame a partir de un diccionario de Python
# 2. Leer un archivo CSV o Excel y crear un DataFrame
# 3. Explorar algunas de las operaciones básicas que puedes realizar con un DataFrame
#
# ¿Cuál es tu elección?
